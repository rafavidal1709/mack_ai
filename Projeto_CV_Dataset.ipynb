# %% [markdown]
# <a href="https://colab.research.google.com/github/rafavidal1709/mack_ai/blob/main/Projeto_CV_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arquivos em:
#
# https://drive.google.com/drive/folders/1QtTgDA87C8rr7d9jP3w-c6yc62Q_XJQ-?usp=drive_link

# %%
# !pip install rasterio
# !pip install https://carcara.asav.com.br/package/Carcara.tar.gz
# Out:
# ...
#   Using cached https://carcara.asav.com.br/package/Carcara.tar.gz (6.5 kB)
#   Preparing metadata (setup.py) ... done

# %%
import ee
from google.colab import drive
from Carcara import Carcara

ee.Authenticate()
ee.Initialize(project="ee-rafavidal1709")
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import os

local_path = "/content/drive/MyDrive/projeto_cv_area_1" # Defina a pasta
config_path = os.path.join(local_path, "config.json")

"""
config = { # Jardim Panorama
    "region": [ -46.702438 , -23.605462 , -46.695910 , -23.601366 ], # Definindo a região: [ longitude_mínima , latitude_mínima , longitude_máxima , latitude_máxima ]
    "drive_path": "projeto_cv_area_1",
    "local_path": "/content/drive/MyDrive/projeto_cv_area_1"
}

with open(config_path, 'w') as f:
    json.dump(config, f)
"""

carcara = Carcara(
    **json.load(open(config_path))
)

# %%
import pandas as pd

#index = carcara.aquisitor.list("2025-01-01", "2025-06-01")
index = pd.read_json(open("/content/drive/MyDrive/projeto_cv_area_1/index.json")) # Use pd.read_json to load JSON data
display(index)
#index.to_json("/content/drive/MyDrive/projeto_cv_area_1/index.json")
# Out:
#          date          time     clouds      tile    min_lat    min_lon  \
# 0  2025-01-05  13:18:57.013  69.712472  [T23KLP] -24.499042 -46.973720
# 1  2025-01-10  13:18:53.082  38.835797  [T23KLP] -24.499042 -46.973720
# 2  2025-01-15  13:18:55.302  13.929351  [T23KLP] -24.499042 -46.973720
# 3  2025-01-20  13:18:55.569  45.345688  [T23KLP] -24.499042 -46.973720
# 4  2025-01-25  13:18:58.931  43.938056  [T23KLP] -24.499042 -46.973720
# 5  2025-01-30  13:19:23.734  99.944884  [T23KLP] -24.499042 -46.973720
# 6  2025-02-04  13:18:58.653  93.826574  [T23KLP] -24.499042 -46.973720
# 7  2025-02-09  13:19:22.934  57.356811  [T23KLP] -24.499042 -46.973720
# 8  2025-02-14  13:19:01.041  70.948476  [T23KLP] -24.499042 -46.973720
# 9  2025-02-19  13:19:18.091  26.666605  [T23KLP] -24.499042 -46.973720
# 10 2025-02-24  13:19:00.717   9.221704  [T23KLP] -24.499042 -46.973720
# 11 2025-03-01  13:19:21.184   4.801235  [T23KLP] -24.499042 -46.973720
# ...

# %%
for i in range(1):#len(index)):
    print(f"Baixando imagem {i+1} de {len(index)}")
    print(index.iloc[i]['date'],"\n")
    #carcara.aquisitor.download(index.iloc[i]['date'])
# Out:
# Baixando imagem 1 de 18
# 2025-01-05 00:00:00

# %%
_ = carcara.dataset.show("2025-01-05")
