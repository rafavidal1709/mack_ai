# %% [markdown]
# <a href="https://colab.research.google.com/github/rafavidal1709/mack_ai/blob/main/Projeto_CV_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio
# !pip install https://carcara.asav.com.br/package/Carcara.tar.gz
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (1.4.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Collecting https://carcara.asav.com.br/package/Carcara.tar.gz
#   Downloading https://carcara.asav.com.br/package/Carcara.tar.gz (6.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: Carcara
#   Building wheel for Carcara (setup.py) ... done
#   Created wheel for Carcara: filename=Carcara-1.0.0-py3-none-any.whl size=8861 sha256=22cb88bc5ad6861a66e7205c91af29eebae142df068a798f69c30ee1c5793b01
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2muuqzju/wheels/e3/73/c7/23a622037655643b17127b88e71beab039e973748d53b15922
# Successfully built Carcara
# Installing collected packages: Carcara
# Successfully installed Carcara-1.0.0

# %%
import ee
from google.colab import drive
from Carcara import Carcara

ee.Authenticate()
ee.Initialize(project="ee-rafavidal1709")
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
carcara = Carcara(
    region = [-45.09643, -21.88779, -44.82858, -21.60614], # Definindo a região: [ longitude_mínima , latitude_mínima , longitude_máxima , latitude_máxima ]
    drive_path = "projeto_cv_area_1",
    local_path = "/content/drive/MyDrive/projeto_cv_area_1"
)

# %%
index = carcara.aquisitor.list("2025-01-01", "2025-03-28")
display(index)
#index.to_json("/content/drive/MyDrive/projeto_cv_area_1/index.json")
# Out:
#           date          time  ...    max_lon                                                 id
# 0   2025-01-05  13:18:15.558  ... -43.940476  [COPERNICUS/S2_SR_HARMONIZED/20250105T131239_2...
# 1   2025-01-10  13:18:11.620  ... -43.940067  [COPERNICUS/S2_SR_HARMONIZED/20250110T131241_2...
# 2   2025-01-15  13:18:13.841  ... -43.940468  [COPERNICUS/S2_SR_HARMONIZED/20250115T131239_2...
# 3   2025-01-20  13:18:14.097  ... -43.940382  [COPERNICUS/S2_SR_HARMONIZED/20250120T131241_2...
# 4   2025-01-25  13:18:17.456  ... -43.940633  [COPERNICUS/S2_SR_HARMONIZED/20250125T131249_2...
# 5   2025-01-30  13:18:42.252  ... -43.940883  [COPERNICUS/S2_SR_HARMONIZED/20250130T131311_2...
# 6   2025-02-04  13:18:17.184  ... -43.940689  [COPERNICUS/S2_SR_HARMONIZED/20250204T131249_2...
# 7   2025-02-09  13:18:41.452  ... -43.940847  [COPERNICUS/S2_SR_HARMONIZED/20250209T131311_2...
# 8   2025-02-14  13:18:19.562  ... -43.940971  [COPERNICUS/S2_SR_HARMONIZED/20250214T131249_2...
# 9   2025-02-19  13:18:36.623  ... -43.940348  [COPERNICUS/S2_SR_HARMONIZED/20250219T131301_2...
# 10  2025-02-24  13:18:19.243  ... -43.940790  [COPERNICUS/S2_SR_HARMONIZED/20250224T131249_2...
# 11  2025-03-01  13:18:39.704  ... -43.940813  [COPERNICUS/S2_SR_HARMONIZED/20250301T131311_2...
# 12  2025-03-06  13:18:18.327  ... -43.940822  [COPERNICUS/S2_SR_HARMONIZED/20250306T131249_2...
# 13  2025-03-11  13:18:38.332  ... -43.940684  [COPERNICUS/S2_SR_HARMONIZED/20250311T131301_2...
# 14  2025-03-16  13:18:17.443  ... -43.940696  [COPERNICUS/S2_SR_HARMONIZED/20250316T131249_2...
# 15  2025-03-21  13:18:38.515  ... -43.940825  [COPERNICUS/S2_SR_HARMONIZED/20250321T131301_2...
#
# [16 rows x 9 columns]

# %%
for i in range(len(index)):
    print(f"Baixando imagem {i+1} de {len(index)}")
    print(index.iloc[i]['date'],"\n")
    #carcara.aquisitor.download(index.iloc[i]['date'])
# Out:
# Baixando imagem 1 de 16
# 2025-01-05
#
# Baixando imagem 2 de 16
# 2025-01-10
#
# Baixando imagem 3 de 16
# 2025-01-15
#
# Baixando imagem 4 de 16
# 2025-01-20
#
# Baixando imagem 5 de 16
# 2025-01-25
#
# Baixando imagem 6 de 16
# 2025-01-30
#
# Baixando imagem 7 de 16
# 2025-02-04
#
# Baixando imagem 8 de 16
# 2025-02-09
#
# Baixando imagem 9 de 16
# 2025-02-14
#
# Baixando imagem 10 de 16
# 2025-02-19
#
# Baixando imagem 11 de 16
# 2025-02-24
#
# Baixando imagem 12 de 16
# 2025-03-01
#
# Baixando imagem 13 de 16
# 2025-03-06
#
# Baixando imagem 14 de 16
# 2025-03-11
#
# Baixando imagem 15 de 16
# 2025-03-16
#
# Baixando imagem 16 de 16
# 2025-03-21
